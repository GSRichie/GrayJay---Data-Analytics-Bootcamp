# %%
import pandas as pd
import io
import requests
import pandas as pd
from zipfile import ZipFile
from bs4 import BeautifulSoup

# %%
url = 'https://www.kijiji.ca/b-cars-vehicles/city-of-toronto/page-2/c27l1700273'

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lte IE 8]><html id="reset" class="ie8" lang="en"><![endif]-->
# <!--[if IE 9]><html id="reset" class="ie9" lang="en"><![endif]-->
# <!--[if gt IE 9]><!-->
# <html id="reset" lang="en">
#  <!--<![endif]-->
#  <!--[if !IE]><!-->
#  <html id="reset" lang="en">
#   <!--<![endif]-->
#   <head>
#    <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#    <link as="style" href="https://ca.classistatic.com/static/V/7665/css/master.theme.css" rel="preload"/>
#    <link as="script" href="https://ca.classistatic.com/static/V/7665/js/bootstrap.js" rel="preload"/>
#    <link as="script" href="https://ca.classistatic.com/static/V/7665/js/common.js" rel="preload"/>
#    <link as="font" crossorigin="" href="//ca.classistatic.com/service-static/frontend-service/Larsseit.92161b1b.woff2" rel="preload" type="font/woff2"/>
#    <link as="font" crossorigin="" href="//ca.classistatic.com/service-static/frontend-service/LarsseitMedium.265c8042.woff2" rel="preload" type="font/woff2"/>
#    <link as="style" href="//ca.classistatic.com/service-static/frontend-service/styles.910334be5fc77a129f18.css" rel="preload"/>
#    <link as="script" href="//ca.classistatic.com/service-static/frontend-service/runtime.d33be267.js" rel="preload"/>
#    <link as="script" href="//ca.classistatic.com/service-static/frontend-service/vendor.e7ffbbc7.js" rel="preload"/>
#    <link as="script" href="//ca.classistatic.com/service-static/frontend-service/app.2214a7bd.js" rel="preload"/>
#    <link as="script" href="//ca.classistatic.com/service-static/frontend-service/searchResults.2660804d.js" rel="preload"/>
#    <link as="script" href="//ca.classistatic.com/service-static/frontend-service/alertPrompt.ce7b92e1.js" rel="preload"/>
#    <link as="script" href="//ca.classistatic.com/service-static/frontend-service/footer.208abb14.js" rel="preload"/>
#    <link as="script" href="//ca.classistatic.com/service-static/frontend-service/header.f2b9f606.js" rel="preload"/>
#    <link as="script" href="//ca.classistatic.com/service-static/frontend-service/showcase.60cff47a.js" rel="preload"/>
#    <link as="script" href="//ca.classistatic.com/service-static/frontend-service/en-i18n-json.afeb9520.js" rel="preload"/>
#    <link as="script" href="//ca.classistatic.com/service-static/frontend-service/styles.0761d611.js" rel="preload"/>
#    <link as="script" href="//ca.classistatic.com/service-static/frontend-service/svg.19e9b5a7.js" rel="preload"/>
#    <title>
#     Browse Local Selection of Used &amp; New Cars &amp; Vehicles in City of Toronto  from Dealers &amp; Private Sellers | Kijiji Classifieds - Page 2
#    </title>
#    <link href="https://ca.classistatic.com/static/V/7665/img/favicons/apple-touch-icon-new.png" rel="apple-touch-icon" sizes="180x180"/>
#    <link href="https://ca.classistatic.com/static/V/7665/img/favicons/favicon-32x32-new.png" rel="icon" sizes="32x32" type="image/png"/>
#    <link href="https://ca.classistatic.com/static/V/7665/img/favicons/favicon-16x16-new.png" rel="icon" sizes="16x16" type="image/png"/>
#    <link href="/manifest.json" rel="manifest"/>
#    <link color="#2c2f6b" href="https://ca.classistatic.com/static/V/7665/img/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
#    <link href="https://ca.classistatic.com/static/V/7665/img/favicons/faviconNew.ico" rel="shortcut icon"/>
#    <meta content="Kijiji" name="apple-mobile-web-app-title"/>
#    <meta content="Kijiji" name="application-name"/>
#    <meta content="/browserconfig.xml" name="msapplication-config"/>
#    <meta content="#2c2f6b" name="theme-color"/>
#    <link href="https://plus.google.com/+KijijiCanada" rel="publisher">
#     <meta content="Find new or used cars in City of Toronto : Honda, BMW, Toyota, Hyundai, Kia, Mazda, Nissan, Chevy, services, parts and make every mile enjoyable." name="description">
#      <meta content="Kijiji, Find, Ads, Cars &amp; Vehicles" name="keywords">
#       <meta content="INDEX,FOLLOW" name="robots">
#        <meta content="app-id=318979520" name="apple-itunes-app">
#         <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#         <meta content="Kijiji" property="og:site_name"/>
#         <meta content="Canada" property="og:country-name"/>
#         <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#         <meta content="E03E7C8B4B4E1A0234A8D2042FD326E8" name="msvalidate.01"/>
#         <meta content="1ca862e94bc07ad7" name="yandex-verification"/>
#         <meta content="nositelinkssearchbox" name="google"/>
#         <meta content="en" http-equiv="content-language"/>
#         <meta content="https://ca.classistatic.com/static/V/7665/img/fb_desktop.jpg" property="og:image">
#          <meta content="website" property="og:type">
#           <meta content="Find new or used cars in City of Toronto : Honda, BMW, Toyota, Hyundai, Kia, Mazda, Nissan, Chevy, services, parts and make every mile enjoyable." property="og:description"/>
#           <meta content="Kijiji Canada" property="og:title"/>
#           <link href="https://www.kijiji.ca/b-cars-vehicles/city-of-toronto/c27l1700273" rel="canonical">
#            <link href="https://www.kijiji.ca/b-cars-vehicles/city-of-toronto/c27l1700273" hreflang="x-default" rel="alternate">
#             <link href="https://www.kijiji.ca/b-cars-vehicles/city-of-toronto/c27l1700273?siteLocale=fr_CA" hreflang="fr" rel="alternate">
#              <script type="application/ld+json">
#               { "@context" : "https://schema.org",
#   "@type" : "Organization",
#   "name" : "Kijiji Canada",
#   "alternateName" : "Kijiji",
#   "url" : "https://www.kijiji.ca/",
#   "sameAs" : [
#     "https://www.facebook.com/Kijiji.ca/",
#     "https://twitter.com/Kijiji",
#     "https://plus.google.com/+KijijiCanada",
#     "https://www.youtube.com/user/kijijicanadacorp",
#     "https://www.linkedin.com/company/kijiji-an-ebay-company",
#     "https://www.wikidata.org/wiki/Q1741191"
#   ],
#   "logo": https://ca.classistatic.com/static/V/7665/img/Kijiji-Canada-Logo-1.jpg
# }
#              </script>
#              <link href="https://ca.classistatic.com/static/V/7665/css/master.theme.css" rel="stylesheet" type="text/css">
#               <link href="https://ca.classistatic.com/static/V/7665/css/srp.theme.css" rel="stylesheet" type="text/css">
#                <link href="https://ca.classistatic.com/static/V/7665/css/redesign.theme.css" rel="stylesheet" type="text/css"/>
#                <link href="https://ca.classistatic.com/static/V/7665/css/redesign-postad.theme.css" rel="stylesheet" type="text/css"/>
#                <link href="//ca.classistatic.com/service-static/frontend-service/styles.910334be5fc77a129f18.css" rel="stylesheet" type="text/css"/>
#                <script src="https://ca.classistatic.com/static/V/7665/js/bootstrap.js">
#                </script>
#                <!--[if lte IE 8]><script defer src="https://ca.classistatic.com/static/V/7665/js/ie8.js"></script><![endif]-->
#                <script defer="" src="//cdn.optimizely.com/js/2217630246.js">
#                </script>
#                <script>
#                 var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
#
# var gptMasterAdData = gptMasterAdData || {};
# var gptCTMAdData = gptCTMAdData || {};
# var gptSizeMaps = gptSizeMaps || {};
# var gptAdSlots = gptAdSlots || {};
# var gptAdTargeting = gptAdTargeting || [];
# var gptBannerSizeMapping = gptBannerSizeMapping || [];
#                </script>
#                <script>
#                 gptSizeMaps.leaderBoard = {
#             breakPoint: [760, 990],
#             responsive: [
#                 { minWidth: 990, sizes: [[728, 90], [970, 90]] },
#                 { minWidth: 760, sizes: [728, 90] },
#                 { minWidth: 0, sizes: [] }
#             ]
#         };
#         gptSizeMaps.inlineBanner = {
#             breakPoint: 961,
#             responsive: [
#                 { minWidth: 961, sizes: [728, 90] },
#                 { minWidth: 0, sizes: [[300, 250], [320, 50], [300, 150]] }
#             ]
#         };
#         gptSizeMaps.baseBanner = {
#             breakPoint: [751, 991],
#             responsive: [
#                 { minWidth: 991, sizes: [[728, 90], [970, 250], [970, 90]] },
#                 { minWidth: 751, sizes: [728, 90] },
#                 { minWidth: 0, sizes: [[300, 250], [320, 50], [300, 150]] }
#             ]
#         };
#         gptSizeMaps.skyscraperBanner = {
#             breakPoint: [751, 1059],
#             responsive: [
#                 { minWidth: 1059, sizes: [[300, 600], [300, 250], [160, 600]] },
#                 { minWidth: 751, sizes: [160, 600] },
#                 { minWidth: 0, sizes: [] }
#             ]
#         };
#         gptSizeMaps.stlBanner = {
#             breakPoint: 840,
#             responsive: [
#                 { minWidth: 840, sizes: [[575, 90],[575, 210]] },
#                 { minWidth: 0, sizes: [350, 90] }
#             ]
#         };
#         gptSizeMaps.topCallToDFPBanner = {
#             breakPoint: 840,
#             responsive: [
#                 { minWidth: 840, sizes: [[575, 200]] },
#                 { minWidth: 0, sizes: [350, 95] }
#             ]
#         };
#         gptSizeMaps.sticky = {
#             breakPoint: 760,
#             responsive: [
#                 { minWidth: 760, sizes: [] },
#                 { minWidth: 0, sizes: [320, 50] }
#             ]
#         };
#                </script>
#                <script>
#                 gptMasterAdData['gpt-leaderboard-top'] = {
#     id: 'gpt-leaderboard-top',
#     slot: '/5138/kij.ca.carsvehicles/srp',
#     sizes: [[728, 90],[970, 90]],sizeMapping: gptSizeMaps.leaderBoard,tile: '1',pos: 'top',
#     collapse: false,
#     isBiddable: true
# };
#
#
#     gptBannerSizeMapping.push({
#         name: 'gpt-leaderboard-top',
#         breakPoint: gptSizeMaps.leaderBoard.breakPoint
#     });
#
#
# gptMasterAdData['gpt-skyscraper'] = {
#     id: 'gpt-skyscraper',
#     slot: '/5138/kij.ca.carsvehicles/srp',
#     sizes: [[300, 600],[300, 250],[160, 600]],sizeMapping: gptSizeMaps.skyscraperBanner,tile: '2',pos: 'top',
#     collapse: false,
#     isBiddable: true
# };
#
#
#     gptBannerSizeMapping.push({
#         name: 'gpt-skyscraper',
#         breakPoint: gptSizeMaps.skyscraperBanner.breakPoint
#     });
#
#
# gptMasterAdData['gpt-minileaderboard-base'] = {
#     id: 'gpt-minileaderboard-base',
#     slot: '/5138/kij.ca.carsvehicles/srp',
#     sizes: [[575, 90],[575, 210]],sizeMapping: gptSizeMaps.stlBanner,tile: '5',
#     collapse: false,
#     isBiddable: false
# };
#
#
#     gptBannerSizeMapping.push({
#         name: 'gpt-minileaderboard-base',
#         breakPoint: gptSizeMaps.stlBanner.breakPoint
#     });
#
#
# gptMasterAdData['gpt-minileaderboard-top'] = {
#     id: 'gpt-minileaderboard-top',
#     slot: '/5138/kij.ca.carsvehicles/srp',
#     sizes: [[575, 200]],sizeMapping: gptSizeMaps.topCallToDFPBanner,tile: '5',
#     collapse: true,
#     isBiddable: false
# };
#
#
#     gptBannerSizeMapping.push({
#         name: 'gpt-minileaderboard-top',
#         breakPoint: gptSizeMaps.topCallToDFPBanner.breakPoint
#     });
#
#
# gptMasterAdData['gpt-leaderboard-base'] = {
#     id: 'gpt-leaderboard-base',
#     slot: '/5138/kij.ca.carsvehicles/srp',
#     sizes: [[728, 90],[970, 250]],sizeMapping: gptSizeMaps.baseBanner,tile: '4',pos: 'base',
#     collapse: false,
#     isBiddable: true
# };
#
#
#     gptBannerSizeMapping.push({
#         name: 'gpt-leaderboard-base',
#         breakPoint: gptSizeMaps.baseBanner.breakPoint
#     });
#
#
# gptMasterAdData['gpt-top-srp'] = {
#     id: 'gpt-top-srp',
#     slot: '/5138/kij.ca.carsvehicles/srp',
#     sizes: [[728, 90], [728, 300]],sizeMapping: gptSizeMaps.inlineBanner,tile: '3',pos: 'bottom',
#     collapse: true,
#     isBiddable: true
# };
#
#
#     gptBannerSizeMapping.push({
#         name: 'gpt-top-srp',
#         breakPoint: gptSizeMaps.inlineBanner.breakPoint
#     });
#
#
# gptMasterAdData['gpt-inline-srp'] = {
#     id: 'gpt-inline-srp',
#     slot: '/5138/kij.ca.carsvehicles/srp',
#     sizes: [[728, 90], [728, 300]],sizeMapping: gptSizeMaps.inlineBanner,tile: '6',pos: 'bottom2',
#     collapse: true,
#     isBiddable: true
# };
#
#
#     gptBannerSizeMapping.push({
#         name: 'gpt-inline-srp',
#         breakPoint: gptSizeMaps.inlineBanner.breakPoint
#     });
#
#
# gptMasterAdData['gpt-sticky'] = {
#     id: 'gpt-sticky',
#     slot: '/5138/kij.ca.carsvehicles/srp',
#     sizes: [[320, 50]],sizeMapping: gptSizeMaps.sticky,tile: '7',pos: 'top',
#     collapse: false,
#     isBiddable: false
# };
#
#
#     gptBannerSizeMapping.push({
#         name: 'gpt-sticky',
#         breakPoint: gptSizeMaps.sticky.breakPoint
#     });
#                </script>
#                <script>
#                 gptAdTargeting.push({ key: 'pagetype', value: 'srp' });
#
#         gptAdTargeting.push({ key: 'sub', value: 'cityoftoronto' });
#
#         gptAdTargeting.push({ key: 'ab', value: '0' });
#
#         gptAdTargeting.push({ key: 'ptg', value: ["KCA23868_0", "KCA26723_1", "KCA28709_1", "KCA28833_0", "KCA29068_1", "KCA29114_3", "KCA29668_0"] });
#
#         gptAdTargeting.push({ key: 'pt', value: 'ResultsBrowse' });
#
#         gptAdTargeting.push({ key: 'city', value: 'torontogta' });
#
#         gptAdTargeting.push({ key: 'l1', value: 'carsvehicles' });
#
#         gptAdTargeting.push({ key: 'ot', value: '1' });
#
#         gptAdTargeting.push({ key: 'g_pn', value: '2' });
#
#         gptAdTargeting.push({ key: 'reg_user', value: 'no' });
#
#         gptAdTargeting.push({ key: 'hn', value: 'kijiji.ca' });
#
#         gptAdTargeting.push({ key: 'ct', value: '27' });
#
#         gptAdTargeting.push({ key: 'catid', value: '27' });
#
#         gptAdTargeting.push({ key: 'dv', value: 'd' });
#
#         gptAdTargeting.push({ key: 'HBL', value: 'yes' });
#
#         gptAdTargeting.push({ key: 'province', value: 'ontario' });
#
#         gptAdTargeting.push({ key: 'g_prebid_version', value: '1.25.0' });
#
#         gptAdTargeting.push({ key: 'lc', value: '1700273' });
#
#         gptAdTargeting.push({ key: 'um', value: '0' });
#
#         gptAdTargeting.push({ key: 'li', value: 'no' });
#
#         gptAdTargeting.push({ key: 'locid', value: '1700273' });
#
#         gptAdTargeting.push({ key: 'pagetest', value: 'largerimagessrp' });
#                </script>
#                <script>
#                 var pbPartnerConfig = pbPartnerConfig || [];
#
#
#     pbPartnerConfig.push({
#         id: 'onedisplay',
#         cpmAdjustment: 0.88,
#         params: {
#             'gpt-rightrail-top':    { network: '9970.1', placement: '4428492' },'gpt-rightrail-bottom': { network: '9970.1', placement: '4428494' },'gpt-vip-leader':       { network: '9970.1', placement: '4428491' },'GPTBigbox':            { network: '9970.1', placement: '4428490' },'gpt-leaderboard-top':  { network: '9970.1', placement: '4428546' },'gpt-top-srp':          { network: '9970.1', placement: '4428515' },'gpt-inline-srp':       { network: '9970.1', placement: '4428522' },'gpt-leaderboard-base': { network: '9970.1', placement: '4428520' },'gpt-skyscraper':       { network: '9970.1', placement: '4428518' },'gpt-leader-bottom':    { network: '9970.1', placement: '4428494' }
#         }
#     });
#
#     pbPartnerConfig.push({
#         id: 'onemobile',
#         cpmAdjustment: 0.88,
#         params: {
#             'gpt-rightrail-top':    { dcn: '2c9d2b4f016464849169adcdb29f0410', pos: 'aol_homepage_top_300x250' },'gpt-rightrail-bottom': { dcn: '2c9d2b4f016464849169adcdb29f0410', pos: 'aol_homepage_bottom_728x90' },'gpt-vip-leader':       { dcn: '2c9d2b4f016464849169adcdb29f0410', pos: 'aol_view_item_page_top_728x90' },'GPTBigbox':            { dcn: '2c9d2b4f016464849169adcdb29f0410', pos: 'aol_view_item_page_bottom_300x250' },'gpt-leaderboard-top':  { dcn: '2c9d2b4f016464849169adcdb29f0410', pos: 'aol_search_results_page_top_728x90' },'gpt-top-srp':          { dcn: '2c9d2b4f016464849169adcdb29f0410', pos: 'aol_search_results_page_inline1_728x90' },'gpt-inline-srp':       { dcn: '2c9d2b4f016464849169adcdb29f0410', pos: 'aol_search_results_page_inline2_728x90' },'gpt-leaderboard-base': { dcn: '2c9d2b4f016464849169adcdb29f0410', pos: 'aol_search_results_page_baseboard_english_728x90' },'gpt-leader-bottom':    { dcn: '2c9d2b4f016464849169adcdb29f0410', pos: 'aol_homepage_bottom_728x90' }
#         }
#     });
#
#     pbPartnerConfig.push({
#         id: 'appnexus',
#         cpmAdjustment: 1,
#         params: {
#             'ImageLeaderBoard':     { placementId: '10477092' },'gpt-r2s-vip':          { placementId: '10477092' },'gpt-posted-vip':       { placementId: '10477092' },'gpt-rightrail-top':    { placementId: '10477237' },'gpt-rightrail-bottom': { placementId: '10477240' },'gpt-vip-leader':       { placementId: '10477242' },'GPTBigbox':            { placementId: '10477243' },'gpt-leaderboard-top':  { placementId: '10477244' },'gpt-top-srp':          { placementId: '10477245' },'gpt-inline-srp':       { placementId: '10477246' },'gpt-leaderboard-base': { placementId: '10477247' },'gpt-skyscraper':       { placementId: '10477248' },'gpt-leader-bottom':    { placementId: '10477240' }
#         }
#     });
#
#     pbPartnerConfig.push({
#         id: 'districtm',
#         cpmAdjustment: 0.9,
#         params: {
#             'ImageLeaderBoard':     { placementId: 9836668 },'gpt-r2s-vip':          { placementId: 9836668 },'gpt-posted-vip':       { placementId: 9836668 },'gpt-rightrail-top':    { placementId: 9836669 },'gpt-rightrail-bottom': { placementId: 9836670 },'gpt-vip-leader':       { placementId: 7058027 },'GPTBigbox':            { placementId: 9527288 },'gpt-leaderboard-top':  { placementId: 9809409 },'gpt-top-srp':          { placementId: 9527281 },'gpt-inline-srp':       { placementId: 7058031 },'gpt-leaderboard-base': { placementId: 9527289 },'gpt-skyscraper':       { placementId: 9527292 },'gpt-leader-bottom':    { placementId: 9836670 }
#         }
#     });
#
#     pbPartnerConfig.push({
#         id: 'districtmDMX',
#         cpmAdjustment: 0.9,
#         params: {
#             'ImageLeaderBoard':     { dmxid: 130920, memberid: 100153 },'gpt-r2s-vip':          { dmxid: 130920, memberid: 100153 },'gpt-posted-vip':       { dmxid: 130920, memberid: 100153 },'gpt-rightrail-top':    { dmxid: 130921, memberid: 100153 },'gpt-rightrail-bottom': { dmxid: 130922, memberid: 100153 },'gpt-vip-leader':       { dmxid: 116615, memberid: 100153 },'GPTBigbox':            { dmxid: 127055, memberid: 100153 },'gpt-leaderboard-top':  { dmxid: 129907, memberid: 100153 },'gpt-top-srp':          { dmxid: 127050, memberid: 100153 },'gpt-inline-srp':       { dmxid: 116617, memberid: 100153 },'gpt-leaderboard-base': { dmxid: 127056, memberid: 100153 },'gpt-skyscraper':       { dmxid: 127058, memberid: 100153 },'gpt-leader-bottom':    { dmxid: 130922, memberid: 100153 }
#         }
#     });
#
#     pbPartnerConfig.push({
#         id: 'ix',
#         cpmAdjustment: 1,
#         params: {
#             'ImageLeaderBoard':     { siteId: '190665' },'gpt-r2s-vip':          { siteId: '190665' },'gpt-posted-vip':       { siteId: '190665' },'gpt-rightrail-top':    { siteId: '190666' },'gpt-rightrail-bottom': { siteId: '190667' },'gpt-vip-leader':       { siteId: '190668' },'GPTBigbox':            { siteId: '190669' },'gpt-leaderboard-top':  { siteId: '190663' },'gpt-top-srp':          { siteId: '190670' },'gpt-inline-srp':       { siteId: '190671' },'gpt-leaderboard-base': { siteId: '190672' },'gpt-skyscraper':       { siteId: '190673' },'gpt-leader-bottom':    { siteId: '190667' }
#         }
#     });
#
#     pbPartnerConfig.push({
#         id: 'openx',
#         cpmAdjustment: 0.85,
#         params: {
#             'ImageLeaderBoard':     { delDomain: 'kijiji-d.openx.net', unit: '538714686' },'gpt-r2s-vip':          { delDomain: 'kijiji-d.openx.net', unit: '538714686' },'gpt-posted-vip':       { delDomain: 'kijiji-d.openx.net', unit: '538714686' },'gpt-rightrail-top':    { delDomain: 'kijiji-d.openx.net', unit: '538714687' },'gpt-rightrail-bottom': { delDomain: 'kijiji-d.openx.net', unit: '538714688' },'gpt-vip-leader':       { delDomain: 'kijiji-d.openx.net', unit: '538714689' },'GPTBigbox':            { delDomain: 'kijiji-d.openx.net', unit: '538714690' },'gpt-leaderboard-top':  { delDomain: 'kijiji-d.openx.net', unit: '538714691' },'gpt-top-srp':          { delDomain: 'kijiji-d.openx.net', unit: '538714692' },'gpt-inline-srp':       { delDomain: 'kijiji-d.openx.net', unit: '538714693' },'gpt-leaderboard-base': { delDomain: 'kijiji-d.openx.net', unit: '538714694' },'gpt-skyscraper':       { delDomain: 'kijiji-d.openx.net', unit: '538714696' },'gpt-leader-bottom':    { delDomain: 'kijiji-d.openx.net', unit: '538714688' }
#         }
#     });
#
#     pbPartnerConfig.push({
#         id: 'pubmatic',
#         cpmAdjustment: 0.92,
#         params: {
#             'ImageLeaderBoard':     { publisherId: '155984', adSlot: 'PUBMATIC_ADFLOW_TOP_ENGLISH_728x90@728x90' },'gpt-r2s-vip':          { publisherId: '155984', adSlot: 'PUBMATIC_ADFLOW_TOP_ENGLISH_728x90@728x90' },'gpt-posted-vip':       { publisherId: '155984', adSlot: 'PUBMATIC_ADFLOW_TOP_ENGLISH_728x90@728x90' },'gpt-rightrail-top':    { publisherId: '155984', adSlot: 'PUBMATIC_HOMEPAGE_TOP_ENGLISH_300x250@300x250' },'gpt-rightrail-bottom': { publisherId: '155984', adSlot: 'PUBMATIC_HOMEPAGE_BOTTOM_ENGLISH_300x250@300x250' },'gpt-vip-leader':       { publisherId: '155984', adSlot: 'PUBMATIC_VIEW_ITEM_PAGE_TOP_ENGLISH_728x90@728x90' },'GPTBigbox':            { publisherId: '155984', adSlot: 'PUBMATIC_VIEW_ITEM_PAGE_BOTTOM_ENGLISH_300x250@300x250' },'gpt-leaderboard-top':  { publisherId: '155984', adSlot: 'PUBMATIC_SEARCH_RESULTS_PAGE_TOP_ENGLISH_728x90@728x90' },'gpt-top-srp':          { publisherId: '155984', adSlot: 'PUBMATIC_SEARCH_RESULTS_PAGE_INLINE1_ENGLISH_728x90@728x90' },'gpt-inline-srp':       { publisherId: '155984', adSlot: 'PUBMATIC_SEARCH_RESULTS_PAGE_INLINE2_ENGLISH_728x90@728x90' },'gpt-leaderboard-base': { publisherId: '155984', adSlot: 'PUBMATIC_SEARCH_RESULTS_PAGE_BASEBOARD_ENGLISH_728x90@728x90' },'gpt-skyscraper':       { publisherId: '155984', adSlot: 'PUBMATIC_SEARCH_RESULTS_PAGE_LEFT_RAIL_ENGLISH_160x600@160x600' },'gpt-leader-bottom':    { publisherId: '155984', adSlot: 'PUBMATIC_HOMEPAGE_BOTTOM_ENGLISH_300x250@300x250' }
#         }
#     });
#
#     pbPartnerConfig.push({
#         id: 'rubicon',
#         cpmAdjustment: 1,
#         params: {
#             'ImageLeaderBoard':     { siteId: '45324', accountId: '12230', zoneId: '582460' },'gpt-r2s-vip':          { siteId: '45324', accountId: '12230', zoneId: '582460' },'gpt-posted-vip':       { siteId: '45324', accountId: '12230', zoneId: '582460' },'gpt-rightrail-top':    { siteId: '45324', accountId: '12230', zoneId: '582464' },'gpt-rightrail-bottom': { siteId: '45324', accountId: '12230', zoneId: '582466' },'gpt-vip-leader':       { siteId: '45324', accountId: '12230', zoneId: '582470' },'GPTBigbox':            { siteId: '45324', accountId: '12230', zoneId: '582472' },'gpt-leaderboard-top':  { siteId: '45324', accountId: '12230', zoneId: '582474' },'gpt-top-srp':          { siteId: '45324', accountId: '12230', zoneId: '582476' },'gpt-inline-srp':       { siteId: '45324', accountId: '12230', zoneId: '582478' },'gpt-leaderboard-base': { siteId: '45324', accountId: '12230', zoneId: '582480' },'gpt-skyscraper':       { siteId: '45324', accountId: '12230', zoneId: '582482' },'gpt-leader-bottom':    { siteId: '45324', accountId: '12230', zoneId: '582466' }
#         }
#     });
#
#     pbPartnerConfig.push({
#         id: 'criteo',
#         cpmAdjustment: 1,
#         params: {
#             'ImageLeaderBoard':     { zoneId: '1257525' },'gpt-r2s-vip':          { zoneId: '1257525' },'gpt-posted-vip':       { zoneId: '1257525' },'gpt-rightrail-top':    { zoneId: '1257543' },'gpt-rightrail-bottom': { zoneId: '1257537' },'gpt-vip-leader':       { zoneId: '1257526' },'GPTBigbox':            { zoneId: '1257538' },'gpt-leaderboard-top':  { zoneId: '1257527' },'gpt-top-srp':          { zoneId: '1257533' },'gpt-inline-srp':       { zoneId: '1257534' },'gpt-leaderboard-base': { zoneId: '1257531' },'gpt-skyscraper':       { zoneId: '1257539' }
#         }
#     });
#                </script>
#                <script>
#                 var pbjs = pbjs || {};
# pbjs.que = pbjs.que || [];
#
#
#
# var PREBID_TIMEOUT = 2000;
# var PREBID_CPM_MAX = 5.00;
#
#
# if (pbPartnerConfig.length > 0) {
#
#
#     var prebidAdUnits = prebidAdUnits || [];
#     var prebidCpmSums = prebidCpmSums || {};
#     var prebidSizes = prebidSizes || [];
#     Kj.Banners.Bidding.constructPrebidAdUnitsV1();
#
#
#     Kj.Banners.Bidding.enableBidderSettings();
#
#
#     if (prebidAdUnits.length > 0) {
#
#
#         pbjs.que.push(function() {
#             pbjs.setConfig({
#                 sizeConfig: prebidSizes,
#                 userSync: {
#                     iframeEnabled: true,
#                     filterSettings: {
#                         iframe: {
#                             bidders: '*',
#                             filter: 'include'
#                         }
#                     }
#                 }
#             });
#             pbjs.onEvent('bidResponse', Kj.Banners.Bidding.monitorCpmTotals);
#             pbjs.aliasBidder('appnexus', 'districtm');
#         });
#
#
#         (function() {
#             var pbjsEl = document.createElement('script');
#             pbjsEl.type = 'text/javascript';
#             pbjsEl.async = true;
#             pbjsEl.src = 'https://ca.classistatic.com/static/V/7665/js/lib/prebid-1.25.0.min.js';
#             var pbjsTargetEl = document.getElementsByTagName('head')[0];
#             pbjsTargetEl.insertBefore(pbjsEl, pbjsTargetEl.firstChild);
#         })();
#
#
#         Kj.Banners.Bidding.requestBidsBeforeGPT(prebidAdUnits, PREBID_TIMEOUT);
#     }
# }
#                </script>
#                <script>
#                 (function () {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') + '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
# })();
#
#
# Kj.Banners.Init.pushAdSizeMaps();
# Kj.Banners.Init.pushAdSlots();
# Kj.Banners.Init.pushAdTargeting();
#
#
# googletag.cmd.push(function() {
#     googletag.pubads().set('adsense_background_color', 'FFFFFF');
#
#
#
#     googletag.enableServices();
#
#
# });
#                </script>
#                <!-- Google Tag Manager -->
#                <script>
#                 var dataLayer = [{"p":{"t":"ResultsBrowse","pl":"Wildebeest","v":"7665","lng":"en_CA","vt":"LST","ua":"python-requests/2.21.0"},"c":{"c":{"id":27,"n":"Cars \u0026 Vehicles"},"l0":{"id":0,"n":"Classifieds"},"l1":{"id":27,"n":"Cars \u0026 Vehicles"}},"l":{"c":{"id":1700273,"n":"City of Toronto"},"l0":{"id":0,"n":"Canada"},"l1":{"id":9004,"n":"Ontario"},"l2":{"id":1700272,"n":"Toronto (GTA)"},"l3":{"id":1700273,"n":"City of Toronto"},"d":""},"u":{"li":false,"tg":{"stg":"KCA29114=3;KCA29668=0;KCA29068=1;KCA28833=0;KCA28709=1;KCA26723=1;KCA23868=0","pagetest":"largerimagessrp"}},"d":{"ua":"python-requests/2.21.0"},"s":{"dcr":false,"tr":100114,"pn":2,"tp":5006,"ps":20,"prc":{},"attr":{},"attrMin":{},"attrMax":{},"srt":{"f":"date","dr":"DESC"},"u":{"li":false,"tg":{"stg":"","pagetest":"largerimagessrp"}},"sr":[{"id":"1404877551","pos":1,"rt":"topad","cr":""},{"id":"1392261121","pos":2,"rt":"topad","cr":""},{"id":"1405222046","pos":3,"rt":"topad","cr":""},{"id":"1386917303","pos":4,"rt":"topad","cr":""},{"id":"1374919336","pos":5,"rt":"topad","cr":""},{"id":"1370685397","pos":6,"rt":"organic","cr":""},{"id":"1409136057","pos":7,"rt":"organic","cr":""},{"id":"1409136677","pos":8,"rt":"organic","cr":""},{"id":"1409137996","pos":9,"rt":"organic","cr":""},{"id":"1409135330","pos":10,"rt":"organic","cr":""},{"id":"1405807323","pos":11,"rt":"organic","cr":""},{"id":"1396675060","pos":12,"rt":"organic","cr":""},{"id":"1396671581","pos":13,"rt":"organic","cr":""},{"id":"1383559496","pos":14,"rt":"organic","cr":""},{"id":"1409137888","pos":15,"rt":"organic","cr":""},{"id":"1409137843","pos":16,"rt":"organic","cr":""},{"id":"1409137508","pos":17,"rt":"organic","cr":""},{"id":"1409136962","pos":18,"rt":"organic","cr":""},{"id":"1384456778","pos":19,"rt":"organic","cr":""},{"id":"1409136131","pos":20,"rt":"organic","cr":""},{"id":"1409136228","pos":21,"rt":"organic","cr":""},{"id":"1409133589","pos":22,"rt":"organic","cr":""},{"id":"1409132995","pos":23,"rt":"organic","cr":""},{"id":"1376743484","pos":24,"rt":"organic","cr":""},{"id":"1384224311","pos":25,"rt":"organic","cr":""}]},"ts":"2019-01-12 18:58:33.194+0000"}];
#     (function (w, d, s, l, i) {
#     w[l] = w[l] || [];
#     w[l].push({'gtm.start': new Date().getTime(), event: 'gtm.js'});
#     var f = d.getElementsByTagName(s)[0],
#             j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#     j.async = true;
#     j.src =
#             '//www.googletagmanager.com/gtm.js?id=' + i + dl;
#     f.parentNode.insertBefore(j, f);
# })(window, document, 'script', 'dataLayer', 'GTM-W4V6');
#                </script>
#                <!-- End Google Tag Manager -->
#                <script crossorigin="anonymous" integrity="sha384-3OWAk6EGlsbQILqFbIlFtvxPK8yN7xluKeyOyhmAHCSN6pgF5bZzvJBPAn0JcRNa" src="https://kijiji-ca.videoplayerhub.com/gallery-1-11-4-kijiji.js">
#                </script>
#                <script async="async" src="https://www.google.com/adsense/search/ads.js">
#                </script>
#                <script charset="utf-8" type="text/javascript">
#                 (function(G,o,O,g,L,e){G[g]=G[g]||function(){(G[g]['q']=G[g]['q']||[]).push(
#     arguments)},G[g]['t']=1*new Date})(window,document,'script','_googCsa');
#                </script>
#                <script src="https://ca.classistatic.com/static/V/7665/js/third-party/aam-dil-v6.12.js">
#                </script>
#                <script>
#                 var dataAAM = dataAAM || {};
#     var kijijiDil = DIL.create({
#         partner: 'kijiji',
#         uuidCookie: { name: 'aam_uuid', days: 30 }
#     });
#
#
#     gptAdTargeting.forEach(function(targeting) {
#         dataAAM[targeting.key] = targeting.value;
#     });
#
#
#     kijijiDil.api.signals(dataAAM, 'c_').submit();
#                </script>
#                <link href="/rss-srp-cars-vehicles/city-of-toronto/page-2/c27l1700273" rel="alternate" type="application/rss+xml"/>
#                <!-- Sunset banner for leq IE 10 -->
#                <script defer="" type="text/javascript">
#                 $(document).ready(function() {
#             if(document.all) {
#                 $('#MainContainer').prepend("<div id=\"IeSunset\">" +
#                     "<h3>Your browser is out of date. Change to a modern browser for a more secure web experience.</h3><ul>" +
#                     "<li class=\"moz\"><a href=\"https://www.mozilla.org/en-US/firefox/new/\" target=\"_blank\" rel=\"noopener noreferrer\"><h4>Mozilla Firefox <span>Download Here</span></h4></a></li>" +
#                     "<li class=\"chrome\"><a href=\"https://www.google.com/chrome/browser/desktop/\" target=\"_blank\" rel=\"noopener noreferrer\"><h4>Google Chrome<span>Download Here</span></h4></a></li>" +
#                     "<li class=\"ie\"><a href=\"https://support.microsoft.com/en-ca/help/17621/internet-explorer-downloads\" target=\"_blank\" rel=\"noopener noreferrer\"><h4>Internet Explorer<span>Download Here</span></h4></a></li>" +
#                     "</ul></div>");
#             }
#         });
#                </script>
#               </link>
#              </link>
#             </link>
#            </link>
#           </link>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </link>
#   </head>
#   <body class="responsive responsive-dp en" id="PageSRP">
#    <div id="FesLoaderTop">
#     <script>
#      window.baseUrl="//ca.classistatic.com/service-static/frontend-service";
#     </script>
#     <script>
#      window.boxUrl="//www.kijiji.ca/";
#     </script>
#    </div>
#    <script src="https://ca.classistatic.com/static/V/7665/js/text/text.js" type="text/javascript">
#    </script>
#    <form style="display:none">
#     <input id="AdsenseQuery" name="query" type="hidden" value=" City of Toronto Toronto (GTA) cars &amp; vehicles"/>
#     <input id="AdsenseQueryShop" name="query" type="hidden" value=" cars &amp; vehicles"/>
#    </form>
#    <script src="https://ca.classistatic.com/static/V/7665/js/text/afs.js" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     Kj.Sponsors.init({
#         maxAds: 6,
#         keepTopBar: true
#     });
#
#
#         var clientIdShop = 'vert-pla-kijiji-ca-cat';
#         var adsenseConfig = {
#             test: 'off',
#             language: 'en',
#             pageType: 'srp',
#             csa: {
#                 top: {
#                     number: 1
#                 },
#                 bottom: {
#                     number: 3
#                 },
#                 page: 2,
#                 repeats: 1,
#                 clientId: 'kijiji-ca-browse2',
#                 clientIdShop: clientIdShop,
#                 query: ' City of Toronto Toronto (GTA) cars &amp; vehicles',
#                 channel: '0_w_brl_27_o_x_2_o_x+kijiji_ca_afs_007+1_w_x_x_x_x_x_x_kca26723_b+1_w_x_x_x_x_x_x_kca28709_b+1_w_x_x_x_x_x_x_kca29068_b+1_w_x_x_x_x_x_x_kca28833_a+1_w_x_x_x_x_x_x_kca23868_a+1_w_x_x_x_x_x_x_kca29114_c',
#                 width: '100%',
#                 isLargeImage: true
#             }
#         };
#
#
#                 adsenseConfig.csa.settingsId = 'be02b44a0a483a849aeace2e92144290';
#
#
#             Kj.AFSh.init(adsenseConfig);
#
#
#         Kj.Adsense.init(adsenseConfig);
#         Kj.Sponsors.chain(Kj.Adsense.api);
#    </script>
#    <script type="text/javascript">
#     var pageTrackingIdentifier = 'Browse Ads';
#     var gaEventLabel = 'L1Cat=Cars & Vehicles;L1Location=Canada;L2Location=Toronto (GTA);L3Location=City of Toronto';
#    </script>
#    <script defer="" src="https://ca.classistatic.com/static/V/7665/js/sponsors/ads/ads.js">
#    </script>
#    <div id="MainContainer">
#     <div class="fes-pagelet">
#      <div data-fes-id="header">
#       <header class="headerElement-3349737891" data-reactroot="" role="banner">
#        <a class="skipToMain-3679500748 button-1997310527 button__primary-1681489609 button__medium-1066667140" href="#mainPageContent" rel=" noopener noreferrer">
#         Skip to main content
#        </a>
#        <div class="printLogo-4110822992">
#         <div class="logo-3282416437" style="visibility:hidden">
#          <a class="logoLink-1425315727" href="/" title="Kijiji">
#           <svg aria-labelledby="kijiji-logo-title" class="icon-459822882 logoLinkIcon-68133637" focusable="false" height="100%" role="img" width="100%">
#            <title id="kijiji-logo-title">
#             Kijiji
#            </title>
#            <use xlink:href="#kijiji-logo">
#            </use>
#           </svg>
#           <svg aria-labelledby="kijiji-logo-mobile-title" class="icon-459822882 logoLinkIconMobile-3507558487" focusable="false" height="100%" role="img" width="100%">
#            <title id="kijiji-logo-mobile-title">
#             Kijiji
#            </title>
#            <use xlink:href="#kijiji-logo-mobile">
#            </use>
#           </svg>
#          </a>
#         </div>
#        </div>
#        <div class="overlay-1946744954">
#        </div>
#        <div class="headerContainer-1051376346">
#         <div class="logoBarWrapper-2331155591">
#          <div class="logoBar-2615648661">
#           <div class="logo-3282416437" style="visibility:hidden">
#            <a class="logoLink-1425315727" href="/" title="Kijiji">
#             <svg aria-labelledby="kijiji-logo-title" class="icon-459822882 logoLinkIcon-68133637" focusable="false" height="100%" role="img" width="100%">
#              <title id="kijiji-logo-title">
#               Kijiji
#              </title>
#              <use xlink:href="#kijiji-logo">
#              </use>
#             </svg>
#             <svg aria-labelledby="kijiji-logo-mobile-title" class="icon-459822882 logoLinkIconMobile-3507558487" focusable="false" height="100%" role="img" width="100%">
#              <title id="kijiji-logo-mobile-title">
#               Kijiji
#              </title>
#              <use xlink:href="#kijiji-logo-mobile">
#              </use>
#             </svg>
#            </a>
#           </div>
#           <div class="headerTools-2066608048">
#            <div class="headerButtons-1611810662">
#             <a class="headerLinkLanguage-2414279999" data-qa-id="language-toggle" href="/?siteLocale=fr_CA" rel="nofollow" title="Français">
#              fr
#             </a>
#             <div class="headerButton-645881860">
#              <a class="headerButtonIconLink-558717184" data-qa-id="header-link-my-messages" href="/m-msg-my-messages/" rel="nofollow noopener noreferrer" title="My Messages">
#               <svg class="icon-459822882" focusable="false" height="100%" role="img" width="100%">
#                <use xlink:href="#icon-messages">
#                </use>
#               </svg>
#               <div class="messagesUnreadCount-1239728541">
#               </div>
#              </a>
#             </div>
#             <div class="root-2862412925">
#              <div class="root-3687532350">
#               <a class="link-2454463992 register-4281208362" href="/t-user-registration.html?targetUrl=L2ItY2Fycy12ZWhpY2xlcy9jaXR5LW9mLXRvcm9udG8vcGFnZS0yL2MyN2wxNzAwMjczXmIvL0xEelBOVzFMSFg4VGJhdC9qVWc9PQ--" rel="nofollow" title="Register">
#                Register
#               </a>
#               <span class="or-4281208362">
#                <!-- -->
#                or
#                <!-- -->
#               </span>
#               <a class="link-2454463992" href="/t-login.html?targetUrl=L2ItY2Fycy12ZWhpY2xlcy9jaXR5LW9mLXRvcm9udG8vcGFnZS0yL2MyN2wxNzAwMjczXmIvL0xEelBOVzFMSFg4VGJhdC9qVWc9PQ--" rel="nofollow" title="Sign In">
#                Sign In
#               </a>
#              </div>
#             </div>
#             <a class="headerButtonPostAd-2493039301" data-qa-id="header-link-post-ad" href="/p-select-category.html" rel="nofollow noopener noreferrer" title="Post ad">
#              Post ad
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="searchBarWrapper-3128709573">
#          <form action="/b-search.html" class="searchBar-2782911640">
#           <input name="formSubmit" type="hidden" value="true"/>
#           <input name="adIdRemoved" type="hidden" value=""/>
#           <input name="adPriceType" type="hidden" value=""/>
#           <input name="brand" type="hidden" value=""/>
#           <input name="carproofOnly" type="hidden" value="false"/>
#           <input name="categoryId" type="hidden" value="27"/>
#           <input name="categoryName" type="hidden" value="Cars &amp; Vehicles"/>
#           <input name="cpoOnly" type="hidden" value="false"/>
#           <input name="dc" type="hidden" value="false"/>
#           <input name="gpTopAd" type="hidden" value="false"/>
#           <input name="highlightOnly" type="hidden" value="false"/>
#           <input name="ll" type="hidden" value=""/>
#           <input name="locationId" type="hidden" value="1700273"/>
#           <input name="minPrice" type="hidden" value=""/>
#           <input name="maxPrice" type="hidden" value=""/>
#           <input name="origin" type="hidden" value=""/>
#           <input name="pageNumber" type="hidden" value="2"/>
#           <input name="searchView" type="hidden" value="LIST"/>
#           <input name="sortByName" type="hidden" value="dateDesc"/>
#           <input name="userId" type="hidden" value=""/>
#           <input name="urgentOnly" type="hidden" value="false"/>
#           <div class="formFieldKeyword-2703177926">
#            <label class="searchLabel-4229750769" for="SearchKeyword">
#             Search
#            </label>
#            <input autocomplete="off" class="inputKeyword-3692124783" data-qa-id="header-field-keyword" id="SearchKeyword" name="keywords" placeholder="Search for anything..." type="text" value=""/>
#            <div>
#            </div>
#           </div>
#           <div class="formFieldCategory-3432574170">
#            <label class="searchLabel-4229750769" for="SearchCategory">
#             Categories
#            </label>
#            <select class="selectCategory-1116892437" id="SearchCategory" name="SearchCategory">
#             <option value="0">
#              All Ads
#             </option>
#             <option value="10">
#              Buy &amp; Sell
#             </option>
#             <option value="72">
#              Services
#             </option>
#             <option selected="" value="27">
#              Cars &amp; Vehicles
#             </option>
#             <option value="112">
#              Pets
#             </option>
#             <option value="800">
#              Vacation Rentals
#             </option>
#             <option value="1">
#              Community
#             </option>
#             <option value="34">
#              Real Estate
#             </option>
#             <option value="45">
#              Jobs
#             </option>
#            </select>
#            <svg class="icon-459822882 selectCategoryIcon-2749838590" focusable="false" height="100%" role="img" width="100%">
#             <use xlink:href="#icon-dropdown">
#             </use>
#            </svg>
#           </div>
#           <div class="formFieldLocationPicker-346936782">
#            <label class="searchLabel-4229750769" for="SearchLocationPicker">
#             Location
#            </label>
#            <input class="inputLocationPicker-3519965181" id="SearchLocationPicker" name="SearchLocationPicker" placeholder="Select location..." readonly="" type="text" value=""/>
#            <svg class="icon-459822882 inputLocationPickerIcon-522011117" focusable="false" height="100%" role="img" width="100%">
#             <use xlink:href="#icon-dropdown">
#             </use>
#            </svg>
#            <div class="locationListContainer-3905147260">
#            </div>
#           </div>
#           <button class="searchSubmit-2947444568" data-qa-id="header-button-submit" name="SearchSubmit" title="Find what you are looking for" type="submit">
#            <svg aria-labelledby="icon-myadssearch-title" class="icon-459822882 searchSubmitIcon-2062811939" focusable="false" height="100%" role="img" width="100%">
#             <title id="icon-myadssearch-title">
#              Find what you are looking for
#             </title>
#             <use xlink:href="#icon-myadssearch">
#             </use>
#            </svg>
#            <span class="searchSubmitText-3139797413">
#             Find what you are looking for
#            </span>
#           </button>
#          </form>
#         </div>
#        </div>
#       </header>
#      </div>
#      <script type="text/javascript">
#       if(rehydrate===undefined){var rehydrate={};}rehydrate["header"]={componentPath:"Shared/Header/Header",props:{}};
#      </script>
#     </div>
#     <ul class="more-searches">
#      <li>
#       Popular:
#      </li>
#      <li>
#       <a class="popular-search" href="/b-cars-vehicles/city-of-toronto/camaro/k0c27l1700273">
#        camaro
#       </a>
#      </li>
#      <li>
#       <a class="popular-search" href="/b-cars-vehicles/city-of-toronto/lamborghini/k0c27l1700273">
#        lamborghini
#       </a>
#      </li>
#      <li>
#       <a class="popular-search" href="/b-cars-vehicles/city-of-toronto/porsche-911/k0c27l1700273">
#        porsche 911
#       </a>
#      </li>
#      <li>
#       <a class="popular-search" href="/b-cars-vehicles/city-of-toronto/car/k0c27l1700273">
#        car
#       </a>
#      </li>
#      <li>
#       <a class="popular-search" href="/b-cars-vehicles/city-of-toronto/toyota/k0c27l1700273">
#        toyota
#       </a>
#      </li>
#      <li>
#       <a class="popular-search" href="/b-cars-vehicles/city-of-toronto/harley-davidson/k0c27l1700273">
#        harley davidson
#       </a>
#      </li>
#      <li>
#       <a class="popular-search" href="/b-cars-vehicles/city-of-toronto/tesla/k0c27l1700273">
#        tesla
#       </a>
#      </li>
#      <li>
#       <a class="popular-search" href="/b-cars-vehicles/city-of-toronto/honda/k0c27l1700273">
#        honda
#       </a>
#      </li>
#      <li>
#       <a class="popular-search" href="/b-cars-vehicles/city-of-toronto/jeep-wrangler/k0c27l1700273">
#        jeep wrangler
#       </a>
#      </li>
#      <li>
#       <a class="popular-search" href="/b-cars-vehicles/city-of-toronto/truck/k0c27l1700273">
#        truck
#       </a>
#      </li>
#     </ul>
#     <div id="MessageContainer">
#     </div>
#     <div id="mainPageContent" tabindex="-1">
#      <div class="fes-pagelet">
#       <div data-fes-id="alertPrompt">
#        <div class="alertPromptContainer-3625631897" data-reactroot="">
#         <span>
#         </span>
#        </div>
#       </div>
#       <script type="text/javascript">
#        if(rehydrate===undefined){var rehydrate={};}rehydrate["alertPrompt"]={componentPath:"Alerts/AlertPrompt",props:{"isEmptyResult":false,"keywords":null,"isLastPage":false,"userEmail":null}};
#       </script>
#      </div>
#      <div class="layout-0 breadcrumbLayout clearfix">
#       <h2 class="icon-link srp-top">
#        <div class="icon cat-post">
#        </div>
#        <a class="post-ad-begin" data-btn-loc="srp-top" href="/p-select-category.html?categoryId=27" rel="nofollow">
#         Post an Ad in this category
#        </a>
#       </h2>
#       <div class="breadcrumb">
#        <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#         <a class="location-selected location-hp" data-id="1700273" href="https://www.kijiji.ca/h-ontario/9004" itemprop="url">
#          <span itemprop="title">
#           Ontario
#          </span>
#         </a>
#        </span>
#        &gt;
#        <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#         <a class="location-selected location-hp" data-id="1700273" href="https://www.kijiji.ca/h-gta-greater-toronto-area/1700272" itemprop="url">
#          <span itemprop="title">
#           Toronto (GTA)
#          </span>
#         </a>
#        </span>
#        &gt;
#        <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#         <a class="location-selected location-hp" data-id="1700273" href="https://www.kijiji.ca/h-city-of-toronto/1700273" itemprop="url">
#          <span itemprop="title">
#           City of Toronto
#          </span>
#         </a>
#        </span>
#        &gt;
#        <span>
#         <h1>
#          Cars &amp; Vehicles in City of Toronto
#         </h1>
#        </span>
#       </div>
#       <div class="centered-item">
#        <div class="outerWrapper">
#         <div class="leaderboardContainer" id="StickyLeaderboard">
#          <div class="banner leaderboard top ad-leader-top breakpoint-750-hide" id="gpt-leaderboard-top">
#           <script>
#            googletag.cmd.push(function () {
#         googletag.display('gpt-leaderboard-top');
#     });
#           </script>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="layout-3">
#       <div class="col-1">
#        <div class="container-primary srp-navigation">
#         <header class="page-tip-trigger" data-content="KijijiAlertTooltip" id="CurrentResultsPageTipTrigger">
#          <strong class="rsp-current-matches">
#           Current Matches
#          </strong>
#          <strong class="rsp-filter-results">
#           Filter Results
#          </strong>
#          <span class="titlecount">
#           (100,114)
#          </span>
#         </header>
#         <div class="content">
#          <h3>
#           Category:
#          </h3>
#          <ul>
#           <li>
#            <a class="category-selected" data-id="0 " href="/b-city-of-toronto/l1700273">
#             All Categories
#            </a>
#           </li>
#           <ul>
#            <li class="highlight">
#             <a href="/b-city-of-toronto/l1700273">
#              ×
#             </a>
#             Cars &amp; Vehicles (100,114)
#            </li>
#            <ul>
#             <li>
#              <a class="category-selected" data-event="ChangeCategory" data-id="31 " href="/b-auto-parts-tires/city-of-toronto/c31l1700273">
#               Vehicle Parts, Tires, &amp; Accessories
#              </a>
#              (65,491)
#             </li>
#             <li>
#              <a class="category-selected" data-event="ChangeCategory" data-id="174 " href="/b-cars-trucks/city-of-toronto/c174l1700273">
#               Cars &amp; Trucks
#              </a>
#              (25,886)
#             </li>
#             <li>
# ...
#       <div class="container-545332043">
#        <svg class="icon-459822882 appStore-2433789617" focusable="false" height="100%" role="img" width="100%">
#         <use xlink:href="#icon-appstore">
#         </use>
#        </svg>
#       </div>
#      </a>
#      <a aria-label="Google Play" href="https://play.google.com/store/apps/details?id=com.ebay.kijiji.ca" rel=" noopener noreferrer" target="_blank" title="Opens in a new window.">
#       <div class="container-545332043">
#        <svg class="icon-459822882 googlePlay-3462882549" focusable="false" height="100%" role="img" width="100%">
#         <use xlink:href="#icon-googleplay">
#         </use>
#        </svg>
#       </div>
#      </a>
#     </div>
#     <div class="socialMediaIcons-1033550445">
#      <div>
#       <a aria-label="Facebook" class="socialMediaIconContainer-2478597958 facebook-1857630538" href="https://www.facebook.com/Kijiji.ca" rel=" noopener noreferrer" target="_blank" title="Opens in a new window.">
#        <svg class="icon-459822882 facebookIcon-3837037485" focusable="false" height="100%" role="img" width="100%">
#         <use xlink:href="#icon-footer-facebook">
#         </use>
#        </svg>
#       </a>
#       <a aria-label="Instagram" class="socialMediaIconContainer-2478597958 instagram-2421956355" href="https://www.instagram.com/kijijicanada/" rel=" noopener noreferrer" target="_blank" title="Opens in a new window.">
#        <svg class="icon-459822882 instagramIcon-3144288999" focusable="false" height="100%" role="img" width="100%">
#         <use xlink:href="#icon-footer-instagram">
#         </use>
#        </svg>
#       </a>
#       <a aria-label="Twitter" class="socialMediaIconContainer-2478597958 twitter-1375412391" href="https://twitter.com/Kijiji" rel=" noopener noreferrer" target="_blank" title="Opens in a new window.">
#        <svg class="icon-459822882 twitterIcon-2392310232" focusable="false" height="100%" role="img" width="100%">
#         <use xlink:href="#icon-footer-twitter">
#         </use>
#        </svg>
#       </a>
#      </div>
#      <div class="iconGroupB-693088378">
#       <a aria-label="Kijiji Central" class="socialMediaIconContainer-2478597958 kijijiCentral-1338662062" href="https://www.kijiji.ca/kijijicentral/?utm_source=Kijiji&amp;utm_medium=FooterIcon" rel=" noopener noreferrer" target="_blank" title="Opens in a new window.">
#        <svg class="icon-459822882 kijijiCentralIcon-2735843417" focusable="false" height="100%" role="img" width="100%">
#         <use xlink:href="#icon-footer-kijijicentral">
#         </use>
#        </svg>
#       </a>
#       <a aria-label="YouTube" class="socialMediaIconContainer-2478597958 youtube-120813017" href="https://www.youtube.com/kijijicanadacorp" rel=" noopener noreferrer" target="_blank" title="Opens in a new window.">
#        <svg class="icon-459822882 youtubeIcon-3637872524" focusable="false" height="100%" role="img" width="100%">
#         <use xlink:href="#icon-footer-youtube">
#         </use>
#        </svg>
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="copyright-2418027893">
#     <p class="copyrightText-2350281792">
#      <span class="copyrightSymbol-2434348717">
#       ©
#      </span>
#      2005-
#      <span>
#       2019
#      </span>
#      Marktplaats BV
#     </p>
#     <p class="copyrightText-2350281792">
#      All rights reserved. Google, Google Play, YouTube and other marks are trademarks of Google Inc.
#     </p>
#    </div>
#   </div>
#  </div>
#  <script type="text/javascript">
#   if(rehydrate===undefined){var rehydrate={};}rehydrate["footer"]={componentPath:"Shared/Footer",props:{}};
#  </script>
# </div>
# <div class="modal-overlay">
# </div>
# <div id="FesLoader">
#  <script type="text/javascript">
#   window.__data={"autosLandingPage":{"loading":{"makes":{"failure":false,"pending":false,"success":false},"models":{"failure":false,"pending":false,"success":false},"inventory":{"failure":false,"pending":false,"success":false}},"makes":[],"models":[],"inventoryCount":null},"config":{"toggleHomepageFeed":false,"requestUrl":"\u002Fb-cars-vehicles\u002Fcity-of-toronto\u002Fpage-2\u002Fc27l1700273","showAdmarktLink":false,"clientType":{"isTablet":false,"isMobile":false,"isDesktop":true,"device":"UNKNOWN (mobile=false, isApple=false)"},"toggleProfileImage":true,"boxInternalUrl":"\u002Fb-search.html","toggleMoveCrossPromotion":true,"requestQueryString":null,"changeLocationURL":"\u002Fb-change-location.html?newLocationId=","searchForm":{"attributeMap":{},"ll":null,"highlightOnly":false,"sortByName":"dateDesc","adPriceType":null,"adIdRemoved":null,"maxPrice":null,"attributeFiltersMax":{},"userId":null,"origin":null,"categoryName":"Cars & Vehicles","keywords":null,"searchView":"LIST","urgentOnly":false,"cpoOnly":false,"gpTopAd":false,"locationId":1700273,"radius":"","attributeFiltersMin":{},"parentCategoryName":"Classifieds","address":"City of Toronto, Ontario","noLocation":false,"minPrice":null,"pageNumber":2,"categoryId":27,"locationPath":"0,9004,1700272,1700273","parentCategorySeoUrl":"\u002Fb-city-of-toronto\u002Fl1700273","carproofOnly":false,"dc":false},"toggleCarproofRebrand":true,"boxInternalQueryString":"categoryId=27&locationId=1700273&pageNum=2&siteLocale=en_CA","userLoggedIn":false,"hashedUserId":null,"toggleMoveCrossPromoInCategorySuggestions":true,"language":"en","toggleRadialSearch":false,"targetUrl":"L2ItY2Fycy12ZWhpY2xlcy9jaXR5LW9mLXRvcm9udG8vcGFnZS0yL2MyN2wxNzAwMjczXmIvL0xEelBOVzFMSFg4VGJhdC9qVWc9PQ--","toggleMoveXpromoAutosLandingPage":true},"locationPicker":{},"postAd":{"categories":{"all":{"level1":{"items":[],"parentId":null},"level2":{"items":[],"parentId":null},"level3":{"items":[],"parentId":null}},"suggested":[],"submittedTitle":""},"packages":{"error":false,"frozen":true,"items":{},"loaded":false,"selected":null},"postAdData":{"editing":false,"insertionFee":{"disclaimer":null,"exists":null,"postingLimit":null,"price":null},"l1CategoryId":null,"isShoppingCart":false,"isRepost":false},"postingLimit":{"adLimit":null,"categoryId":null,"categoryName":"","isAdmarktCategory":null,"isAdmarktUser":null,"isNewAd":null},"categoryConfig":[],"location":{"savedLocation":null,"postingLocation":null,"showExactLocation":true,"editingLocation":false,"locationApiLoadFailed":false},"loading":{"categories":{"all":{"failure":false,"pending":false,"success":false},"suggested":{"failure":false,"pending":false,"success":false}},"postAdData":{"failure":false,"pending":false,"success":false},"categoryConfig":{"failure":false,"pending":false,"success":false},"location":{"failure":false,"pending":false,"success":false}}},"messageBox":{"unreadCount":{"total":0,"asPoster":0,"asReplier":0},"loaded":false,"banners":{},"deleting":false,"activeConversation":{"loading":false,"loaded":false,"blockLoading":false,"failed":false,"data":{}},"totalCount":0,"prefetching":false,"roleFilter":"All","conversations":[],"unseenNotificationCount":0,"pageNum":0,"selected":[],"loading":false,"allSelected":false,"failed":false,"conversationCache":[]},"homepageGallery":{"ads":[],"firstLoad":true,"loading":false,"loaded":false},"recentlyViewedAds":{"loading":{"failure":false,"pending":false,"success":false},"ads":[]},"ebaySponsor":{"ads":[],"loading":false,"loaded":false},"viewItemPage":{"loading":false,"loaded":false,"viewItemData":{},"isModalMapOpen":false},"banners":{"rendered":{}},"myKijiji":{"myAds":{"ads":{"adsDirectory":{},"sortedAdIds":[],"requestedAds":{},"filtering":{"activeFilter":"active","currentSort":{"active":{"field":"sortableEndDate","ascending":true},"inactive":{"field":"sortableEndDate","ascending":true}},"search":""},"currentPage":1,"overheadMessageError":null},"promotions":{"totalPrice":0,"selectedfeatureIds":[],"sellingPoint":"MY_KIJIJI"},"l ...
#  </script>
#  <script defer="" src="//ca.classistatic.com/service-static/frontend-service/runtime.d33be267.js">
#  </script>
#  <script defer="" src="//ca.classistatic.com/service-static/frontend-service/vendor.e7ffbbc7.js">
#  </script>
#  <script defer="" src="//ca.classistatic.com/service-static/frontend-service/app.2214a7bd.js">
#  </script>
#  <script defer="" src="//ca.classistatic.com/service-static/frontend-service/searchResults.2660804d.js">
#  </script>
#  <script defer="" src="//ca.classistatic.com/service-static/frontend-service/alertPrompt.ce7b92e1.js">
#  </script>
#  <script defer="" src="//ca.classistatic.com/service-static/frontend-service/footer.208abb14.js">
#  </script>
#  <script defer="" src="//ca.classistatic.com/service-static/frontend-service/header.f2b9f606.js">
#  </script>
#  <script defer="" src="//ca.classistatic.com/service-static/frontend-service/showcase.60cff47a.js">
#  </script>
#  <script defer="" src="//ca.classistatic.com/service-static/frontend-service/en-i18n-json.afeb9520.js">
#  </script>
#  <script defer="" src="//ca.classistatic.com/service-static/frontend-service/styles.0761d611.js">
#  </script>
#  <script defer="" src="//ca.classistatic.com/service-static/frontend-service/svg.19e9b5a7.js">
#  </script>
# </div>
# <script type="text/javascript">
#  window.__apolloData={"$ROOT_QUERY.suggestKeyword":{"query":"","categoryId":0,"selected":false,"__typename":"SuggestKeyword"},"ROOT_QUERY":{"suggestKeyword":{"type":"id","generated":true,"id":"$ROOT_QUERY.suggestKeyword","typename":"SuggestKeyword"},"__typename":"SuggestKeywordQuery"}};
# </script>
# <script src="https://ca.classistatic.com/static/V/7665/js/pages/cguid.js">
# </script>
# <script src="https://ca.classistatic.com/static/V/7665/js/common.js">
# </script>
# <!-- BUNDLE: _ -->
# <!-- END BUNDLE: _ -->
# <!-- BUNDLE: gpt -->
# <!-- END BUNDLE: gpt -->
# <script defer="" src="https://ca.classistatic.com/static/V/7665/js/legacy-page-controllers/watchlistPanel.js" type="text/javascript">
# </script>
# <div id="WatchlistContainer">
#  <header>
#   <div class="watchlist-star-small">
#   </div>
#   <h3>
#    My Favourites (
#    <span id="WatchListCount">
#    </span>
#    )
#   </h3>
#   <div class="watchlist-tab-arrow">
#   </div>
#  </header>
#  <div class="body">
#   <div class="content">
#    <div class="title">
#     Recently Added:
#    </div>
#    <div class="view-all">
#     <a href="/m-watch-list.html">
#      View all
#     </a>
#    </div>
#    <div id="Watchlist">
#     <ul id="WatchlistItems">
#     </ul>
#    </div>
#   </div>
#  </div>
# </div>
# <script src="https://ca.classistatic.com/static/V/7665/js/srp.js" type="text/javascript">
# </script>
# <script defer="" src="https://ca.classistatic.com/static/V/7665/js/templates.js">
# </script>
# <script type="text/javascript">
#  $(document).ready(function () {
#         var data = window.dataLayer ? dataLayer[0] : [];
#         Zoop.init({
#             data: {dl: data},
#             config: {
#                 url: "/j-page-view.json",
#                 token: "1547319512909.2b304d9dacb355b8f00517093311d5207fbdec4ce18147c63c3b82ac5d4585fe"
#             }
#         });
#         Zoop.callEvent({
#             data: {}
#         });
#     });
# </script>
# <script type="text/javascript">
#  Kj.extVars = {
#         validationMessages : {
#             group : "Please correct the errors below:",
#             req : "Please enter information above.",
#             email : "Please enter a valid email address.",
#             number : "Please enter a valid number.",
#             phone: "Please provide a valid phone number.",
#             maxlength : "Sorry, our limit is {{max}} characters. Please shorten your message.",
#             minlength: "Input needs to be at least {{min}} characters.",
#             numberRange: "Please enter a value between {{min}} and {{max}}.",
#             numberMax: "Please enter a value no greater than {{max}}.",
#             numberMin: "Please enter a value of at least {{min}}.",
#             fileType: "One or more image(s) failed to upload. File format not supported.",
#             fileSize: "One or more image(s) failed to upload. File size limit exceeded.",
#             matching: "Input does not match above",
#             headline: "Please correct the following before continuing:",
#             creditcard: "Please correct your credit card number.",
#             radioButton: "Please select option above.",
#             postalCode: "Please provide a valid Postal Code.",
#             websiteUrl: "Website URL is invalid, please check your input."
#         },
#         tracking : {
#             page: "Browse Ads",
#             locId: "1700273",
#             catId: "27",
#             adOrUserNotFound: false
#         },
#         domainUrl : ".kijiji.ca",
#         locale: "en_CA",
#         facebook: {
#             requiredPermissions: "We require permission to access your email address, please try again with the correct permissions.",
#             error: "An error has occurred with Facebook login. Please try again."
#         },
#         isTestEnvironment: false,
#         staticUrl: "https://ca.classistatic.com/static/V/7665/"
#
#     };
#
#     $(document).ready(function() {
#
#
#         Kj.Tracking.initTrackAttributeSelection();
#         Kj.Tracking.initTrackPostAdBeginButtons();
#         Kj.Tracking.initTrackUserAccountActions({
#             isDealer: false
#         });
#         Kj.Tracking.initTrackAdActivation();
#         Kj.Tracking.TrackHelpDesk.init();
#         Kj.Tracking.initAddLinkerParam();
#         Kj.initHoverButtons();
#         Kj.initToggleButtons();
#         Kj.initCollapseCategories();
#         Kj.initHistoryBackLink();
#         Kj.Banners.BannerRendered.init();
#         Kj.initPrintLinks();
#         Kj.initAdChoice();
#
#             Kj.Banners.AdBlock.init();
#
#         Belen.Controller.Search.extVars = {
#             staticContentBaseUrl: 'https://ca.classistatic.com/static/V/7665',
#             editWatchlistAjaxUrl: '/j-edit-watchlist.json',
#             getWatchlistEntryAjaxUrl: '/j-get-watchlist-item.json',
#             watchlistTitleAdd: 'Click to add to My Favourites',
#             watchlistTitleRemove: 'Saved to My Favourites'
#         };
#         Belen.Controller.Search.Watchlist.init();
#
#         //Check for undefined override.
#         if (typeof undefined !== 'undefined') {
#             console.warn('HEY! Something is overwriting `undefined`. Don\'t ship!');
#         }
#     });
# </script>
# <script src="//pulsar.ebay.com/plsr/mpe/0/KIJI/9?pld=%5B%7B%22plsUBT%22%3A1%2C%22ea%22%3A%22VIEW%22%2C%22pge%22%3A2351445%2C%22app%22%3A%22KijijiApp%22%7D%5D&amp;getCGuid=1&amp;cache=0.24303798959590495&amp;callback=pulsarCallback" type="text/javascript">
# </script>
# <noscript>
#  <style>
#   .jsonly {
#             display: none;
#         }
#         .jshidden {
#             display: block;
#         }
#  </style>
#  <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-W4V6" style="display:none;visibility:hidden" width="0">
#  </iframe>
# </noscript>
# <script type="text/javascript">
#  $(document).ready(function() {
#
#
#         Kj.extVars.search = {
#             page: 2,
#             hasKeywords: false,
#             suid: Math.round(Math.random() * 10000000000000).toString(36) // TODO: Fake search CID, backend to inject real one.
#         };
#         Kj.Search.initDistanceSlider({
#             distanceLabel : 'Drag Me',
#             distanceMax : 500,
#             radius : '100',
#             address : 'City of Toronto'
#         });
#
#             if ($('.zero-results').length == 0) {
#                 Kj.Search.initStickyScyscraper();
#                 Kj.Search.initStickyLeaderboard();
#             }
#
#         Kj.initToolTips();
#         Kj.Search.initSearchFilters();
#         Kj.Listings.initAlertSubscribe({
#             emailAlertSubscribeUrl: '/j-subscribe-alerts.json',
#             keywordSearch: '',
#             language: 'en'
#         });
#         Kj.Listings.initSearchResults({
#             featureCounterUrl: '/j-feature-link-inc.json',
#             hasDealerRatings: false,
#             hasSponsors: false
#         });
#
#
#         Kj.Listings.initEmbeddedTopAd();
#
#         Kj.RecentlyViewed.initRecentlyViewed("https://ca.classistatic.com/static/V/7665/img/placeholder.gif");
#
#
#
#         Kj.Search.initSearchNavigationFlag();
#         Kj.Search.initFakePageLinks();
#
#         Kj.Search.SearchNav.init();
#         Kj.Banners.Responsive.init({
#             banners: window.gptBannerSizeMapping
#         });
#
#
#     });
# </script>

# %%
CarMake_df = pd.read_csv("car2db_en_cut\car_make.csv")

# %%
CarMake_df.head()
# Out:
#   'id_car_make'      'name' 'date_create' 'date_update' 'id_car_type'
# 0          '76'     'Honda'  '1398977406'  '1524767226'           '1'
# 1          '80'  'Infiniti'  '1398977406'  '1524767227'           '1'
